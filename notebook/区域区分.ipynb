# %% [markdown]
# # 区域区分

# %% [markdown]
# ## shapeファイルの表示

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# shapeファイルのパスを指定
shapefile_path = '../shape_org/28_兵庫県/28201_姫路市/28201_senbiki.shp'

# GeoDataFrameを表示
gdf = gpd.read_file(shapefile_path)
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax)
plt.show()

# 属性情報をDataFrameとして取得
attr_df = pd.DataFrame(gdf.drop(columns='geometry'))
display(attr_df)
# Out:
#        区域区分  kubunID Pref Citycode Cityname  当初決定日      最終告示日  決定区分   決定者  \
# 0   市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 1     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 2     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 3     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 4     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 5     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 6     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 7     市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 8   市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 9   市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 10  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 11    市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 12  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 13  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 14  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 15  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 16  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 17  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 18  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 19  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 20  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 21    市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 22    市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 23  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 24  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 25  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 26  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 27  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 28    市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 29  市街化調整区域       23  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
# 30    市街化区域       22  兵庫県    28201      姫路市    NaN  令和3年3月31日   NaN  None
#
#     告示番号S       告示番号L
# 0     NaN  兵庫県告示第420号
# 1     NaN  兵庫県告示第420号
# 2     NaN  兵庫県告示第420号
# 3     NaN  兵庫県告示第420号
# 4     NaN  兵庫県告示第420号
# 5     NaN  兵庫県告示第420号
# 6     NaN  兵庫県告示第420号
# 7     NaN  兵庫県告示第420号
# 8     NaN  兵庫県告示第420号
# 9     NaN  兵庫県告示第420号
# 10    NaN  兵庫県告示第420号
# 11    NaN  兵庫県告示第420号
# 12    NaN  兵庫県告示第420号
# 13    NaN  兵庫県告示第420号
# 14    NaN  兵庫県告示第420号
# 15    NaN  兵庫県告示第420号
# 16    NaN  兵庫県告示第420号
# 17    NaN  兵庫県告示第420号
# 18    NaN  兵庫県告示第420号
# 19    NaN  兵庫県告示第420号
# 20    NaN  兵庫県告示第420号
# 21    NaN  兵庫県告示第420号
# 22    NaN  兵庫県告示第420号
# 23    NaN  兵庫県告示第420号
# 24    NaN  兵庫県告示第420号
# 25    NaN  兵庫県告示第420号
# 26    NaN  兵庫県告示第420号
# 27    NaN  兵庫県告示第420号
# 28    NaN  兵庫県告示第420号
# 29    NaN  兵庫県告示第420号
# 30    NaN  兵庫県告示第420号

# %% [markdown]
# ## shapeファイルの結合

# %% [markdown]
# 「28_兵庫県」ディレクトリ内にある'_douro.shp'ファイルのリストを作成する。

# %%
import os
import pprint 
from typing import List

def find_shp_files(root_dir: str, keyword: str ) -> List[str]:
 
    file_list = []
    for root, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.shp') and keyword in file:
                file_list.append(os.path.join(root, file))
    return file_list


root_directory = '../shape_org/41_佐賀県'
file_list = find_shp_files(root_directory,'_senbiki')
pprint.pprint(file_list)
# Out:
# ['../shape_org/41_佐賀県/41201_佐賀市/41201_senbiki.shp',
#  '../shape_org/41_佐賀県/41341_基山町/41341_senbiki.shp',
#  '../shape_org/41_佐賀県/41203_鳥栖市/41203_senbiki.shp']

# %% [markdown]
# 全市区町村のshapeファイルを結合する。

# %%
import geopandas as gpd
import pandas as pd


def merge_shapefiles(file_list: List[str], encoding: str = 'shift-jis') -> gpd.GeoDataFrame:
    gdfs = [gpd.read_file(file, encoding=encoding) for file in file_list]
    return pd.concat(gdfs, ignore_index=True)


merged_gdf = merge_shapefiles(file_list)
    
# GeoDataFrameを表示
fig, ax = plt.subplots(figsize=(10, 10))
merged_gdf .plot(ax=ax)
plt.show()

# 属性情報をDataFrameとして取得
attr_df = pd.DataFrame(merged_gdf.drop(columns='geometry'))
display(attr_df)
# Out:
#        区域区分  kubunID Pref Citycode Cityname  当初決定日 最終告示日  決定区分   決定者  告示番号S  \
# 0     市街化区域       22  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 1     市街化区域       22  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 2     市街化区域       22  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 3     市街化区域       22  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 4     市街化区域       22  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 5   市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 6   市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 7   市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 8   市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 9   市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 10  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 11  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 12  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 13  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 14  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 15  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 16  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 17  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 18  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 19  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 20  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 21  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 22  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 23  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 24  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 25  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 26  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 27  市街化調整区域       23  佐賀県    41201      佐賀市    NaN  None   NaN  None    NaN
# 28    市街化区域       22  佐賀県    41341      基山町    NaN  None   NaN  None    NaN
# 29    市街化区域       22  佐賀県    41341      基山町    NaN  None   NaN  None    NaN
# 30    市街化区域       22  佐賀県    41341      基山町    NaN  None   NaN  None    NaN
# 31    市街化区域       22  佐賀県    41341      基山町    NaN  None   NaN  None    NaN
# 32  市街化調整区域       23  佐賀県    41341      基山町    NaN  None   NaN  None    NaN
# 33    市街化区域       22  佐賀県    41203      鳥栖市    NaN  None   NaN  None    NaN
# 34  市街化調整区域       23  佐賀県    41203      鳥栖市    NaN  None   NaN  None    NaN
#
#    告示番号L
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None
# 28  None
# 29  None
# 30  None
# 31  None
# 32  None
# 33  None
# 34  None

# %% [markdown]
# ## kmlへの変換

# %% [markdown]
# 市街化区域と市街化調整区域の2つのkmlファイルを作成する。

# %%
def split_gdf(gdf):
    # '区域区分'の一覧を取得
    list = gdf['区域区分'].unique()
    
    # 各区域区分ごとにGeoDataFrameを分割
    split_gdfs = {i: gdf[gdf['区域区分'] == i] for i in list}

    
    return split_gdfs

# 使用例
split_gdfs = split_gdf(merged_gdf)

# %%
import os
import geopandas as gpd
import xml.etree.ElementTree as ET

def reduce_coordinate_precision(coords, precision):
    return [(round(x, precision), round(y, precision)) for x, y in coords]

def create_kml_polygon(coordinates, name, description, style_url):
    placemark = ET.Element('Placemark')
    ET.SubElement(placemark, 'name').text = name
    ET.SubElement(placemark, 'description').text = description
    ET.SubElement(placemark, 'styleUrl').text = style_url
    
    polygon = ET.SubElement(placemark, 'Polygon')
    outer_boundary = ET.SubElement(polygon, 'outerBoundaryIs')
    linear_ring = ET.SubElement(outer_boundary, 'LinearRing')
    coords = ET.SubElement(linear_ring, 'coordinates')
    
    coord_str = ' '.join([f"{x},{y},0" for x, y in coordinates])
    coords.text = coord_str
    
    return placemark

def create_style(style_id, color):
    style = ET.Element('Style', id=style_id)
    line_style = ET.SubElement(style, 'LineStyle')
    ET.SubElement(line_style, 'color').text = color
    ET.SubElement(line_style, 'width').text = '2'
    poly_style = ET.SubElement(style, 'PolyStyle')
    ET.SubElement(poly_style, 'color').text = color.replace('ff', '80')  # 50% transparency
    return style

def save_split_gdfs_to_kml(split_gdfs, output_dir, coordinate_precision=6):
    os.makedirs(output_dir, exist_ok=True)
    
    total_gdfs = len(split_gdfs)
    for i, (kubun, gdf) in enumerate(split_gdfs.items(), 1):
        filename = f"{kubun.replace(' ', '_')}.kml"
        filepath = os.path.join(output_dir, filename)
        
        gdf_wgs84 = gdf.to_crs("EPSG:4326")
        
        kml = ET.Element('kml', xmlns="http://www.opengis.net/kml/2.2")
        document = ET.SubElement(kml, 'Document')
        
        # スタイルの定義
        style_ids = {
            '市街化区域': 'style_shigaika',
            '市街化調整区域': 'style_chosei'
        }
        document.append(create_style(style_ids['市街化区域'], 'ff0000ff'))  # 赤色
        document.append(create_style(style_ids['市街化調整区域'], 'ff00ff00'))  # 緑色
        
        for _, row in gdf_wgs84.iterrows():
            geom = row['geometry']
            kuiki_kubun = row['区域区分']
            name = kuiki_kubun
            description = "<![CDATA["
            description += f"<h3>{kuiki_kubun}</h3>"
            description += "<table border='1'><tr><th>属性</th><th>値</th></tr>"
            for col in gdf_wgs84.columns:
                if col not in ['geometry', '区域区分']:
                    description += f"<tr><td>{col}</td><td>{row[col]}</td></tr>"
            description += "</table>]]>"
            
            style_url = f"#{style_ids.get(kuiki_kubun, 'style_shigaika')}"
            
            if geom.geom_type == 'Polygon':
                coords = reduce_coordinate_precision(list(geom.exterior.coords), coordinate_precision)
                placemark = create_kml_polygon(coords, name, description, style_url)
                document.append(placemark)
            elif geom.geom_type == 'MultiPolygon':
                for poly in geom.geoms:
                    coords = reduce_coordinate_precision(list(poly.exterior.coords), coordinate_precision)
                    placemark = create_kml_polygon(coords, name, description, style_url)
                    document.append(placemark)
        
        tree = ET.ElementTree(kml)
        tree.write(filepath, encoding='utf-8', xml_declaration=True)
        
        print(f"保存完了 ({i}/{total_gdfs}): {filepath}")
    
    print(f"\n全ての区域区分のKMLファイルが {output_dir} に保存されました。")

# 使用例
output_directory = "../kml_google_map"
save_split_gdfs_to_kml(split_gdfs, output_directory, coordinate_precision=7)

# 保存されたファイルの確認
saved_files = os.listdir(output_directory)
print("\n保存されたファイル:")
for file in saved_files:
    print(f" - {file}")
    file_size = os.path.getsize(os.path.join(output_directory, file)) / 1024  # KBに変換
    print(f"   サイズ: {file_size:.2f} KB")
# Out:
# 保存完了 (1/2): ../kml_google_map/市街化区域.kml
# 保存完了 (2/2): ../kml_google_map/市街化調整区域.kml
#
# 全ての区域区分のKMLファイルが ../kml_google_map に保存されました。
#
# 保存されたファイル:
#  - 市街化区域.kml
#    サイズ: 447.50 KB
#  - 市街化調整区域.kml
#    サイズ: 666.55 KB
